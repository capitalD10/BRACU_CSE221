# %% [markdown]
# ![ques.PNG](data:image/png;base64,...)

# %%
N, M = list(map(int, input().split()))
graph = [[0] * N for i in range(N)]
for x in range(M):
  nod1, nod2, cost = list(map(int, input().split()))
  graph[nod1 - 1][nod2 - 1] = cost
for x in range(N):
  for y in range(N):
    print(graph[x][y], end=" ")
  print()
# Out:
# 4 3
# 1 3 8
# 3 2 5
# 1 4 2
# 0 0 8 2
# 0 0 0 0
# 0 5 0 0
# 0 0 0 0
