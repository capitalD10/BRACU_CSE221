# %% [markdown]
# ![ques.PNG](data:image/png;base64,...)

# %%
T = int(input())
result = []
for _ in range(T):
    N = int(input())
    result.append(int((N * (N + 1)) / 2))
for x in result:
  print(x)
# Out:
# 5
# 2
# 5
# 10
# 12
# 100
# 3
# 15
# 55
# 78
# 5050
