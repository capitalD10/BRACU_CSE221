# %% [markdown]
# ![ques.PNG](data:image/png;base64,...)

# %%
def fastMOD(a, b):
  res = 1
  a = a % 107
  if not a:
    return 0
  while b > 0:
    if b % 2 != 0:
      res = (res * a) % 107
    a = (a * a) % 107
    b //= 2
  return res
a, b = list(map(int, input().split()))
print(fastMOD(a, b))
# Out:
# 100 3
# 85
