# %% [markdown]
# ![ques.PNG](data:image/png;base64,...)

# %%
N = int(input())
arr = list(map(int, input().split()))
max_sum = -1
max_i = 0
j = 1
while j < len(arr):
  new_sum = arr[max_i] + (arr[j]) ** 2
  max_sum = max(max_sum, new_sum)
  if arr[max_i] >= arr[j]:
    max_i = max_i
  else:
    max_i = j
  j += 1
print(max_sum)
# Out:
# 5
# 4 3 1 5 6
# 41
